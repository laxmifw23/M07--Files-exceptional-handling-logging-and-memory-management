# %% [markdown]
# # Files, exceptional handling,logging and memory management
# # Assignment Q&A
# '''01. What is the difference between interpreted and compiled languages'''
# - Interpreted vs Compiled Languages:
# Interpreted languages, like Python and JavaScript, execute code line-by-line without compiling it first. This allows for dynamic typing and flexibility. Compiled languages, like C and C++, translate code into machine code before execution, resulting in faster performance. Interpreted languages are typically easier to develop and debug, while compiled languages provide better performance and security. The choice between the two depends on the project's requirements and goals. This affects development speed, performance, and security.

# %% [markdown]
# '''02. What is exception handling in Python'''
# - Exception Handling in Python:
# Exception handling is a mechanism to handle runtime errors in Python. It allows you to catch and manage exceptions, preventing program crashes. Using try-except blocks, you can catch specific exceptions, handle them, and provide meaningful error messages. This ensures your program remains stable and provides useful feedback instead of crashing. Exception handling is crucial for writing robust and reliable Python code, enabling you to handle unexpected errors and edge cases effectively. It improves overall code quality and user experience

# %% [markdown]
# '''03. What is the purpose of the finally block in exception handling'''
# - The finally block in exception handling ensures that certain code executes regardless of whether an exception occurred. It's typically used for cleanup actions, such as closing files, releasing resources, or logging. The finally block runs after the try and except blocks, providing a way to perform necessary tasks even if an exception is thrown or caught.

# %% [markdown]
# '''04. What is logging in Python'''
# - Logging in Python is a mechanism to track events in a program. It provides a way to record information, warnings, and errors, helping with debugging and monitoring. Python's built-in logging module allows you to log messages at different levels, such as debug, info, warning, error, and critical, making it easier to diagnose and resolve issues.

# %% [markdown]
# '''05. What is the significance of the __del__ method in Python'''
# - The __del__ method in Python is a special method called when an object is about to be destroyed. It's used for cleanup actions, such as releasing resources, closing files, or freeing memory. This method is crucial for preventing memory leaks and ensuring that objects are properly cleaned up when they're no longer needed, promoting efficient memory management.

# %% [markdown]
# '''06. What is the difference between import and from ... import in Python'''
# - In Python, import imports an entire module, while from ... import imports specific components. With import, you access module contents using the module's name as a prefix. With from ... import, you access imported components directly. Import avoids namespace pollution, while from ... import can lead to it. Use import for modules with many components or when you want to avoid namespace pollution. Use from ... import for modules with few components or when you want to simplify your code. This choice affects code readability and maintainability.

# %% [markdown]
# '''07. How can you handle multiple exceptions in Python'''
# - You can handle multiple exceptions in Python using a single except block with multiple exception types or multiple except blocks for each exception type. For example: except (TypeError, ValueError) or separate except blocks for TypeError and ValueError. This allows for flexible error handling.

# %% [markdown]
# '''08. What is the purpose of the with statement when handling files in Python'''
# - The with statement in Python ensures that files are properly closed after use, regardless of whether an exception occurs. It automatically handles file closure, eliminating the need for explicit close() calls. This approach prevents file descriptor leaks, reduces resource usage, and improves code readability and reliability when working with files.

# %% [markdown]
# '''09. What is the difference between multithreading and multiprocessing'''
# - Multithreading involves executing multiple threads within a single process, sharing memory and resources. Multiprocessing involves running multiple processes, each with its own memory and resources. Multithreading is suitable for I/O-bound tasks, while multiprocessing is better for CPU-bound tasks, allowing true parallel execution and improved performance on multi-core systems.

# %% [markdown]
# '''10. What are the advantages of using logging in a program'''
# - Logging provides several benefits, including improved debugging, error tracking, and performance monitoring. It helps identify issues, understand program flow, and troubleshoot problems. Logging also enables auditing, security monitoring, and compliance reporting, making it an essential tool for developing and maintaining robust, reliable, and maintainable software applications.

# %% [markdown]
# '''11. What is memory management in Python'''
# - Python's memory management is automatic, using a garbage collector to reclaim memory occupied by objects no longer in use. It handles memory allocation and deallocation for objects, such as strings, lists, and dictionaries. This approach simplifies development, but can lead to memory issues if not properly managed, such as memory leaks or fragmentation.

# %% [markdown]
# '''12. What are the basic steps involved in exception handling in Python'''
# - The basic steps involved in exception handling in Python are: (1) Try: Enclose code that may raise an exception. (2) Except: Catch and handle specific exceptions. (3) Except (multiple exceptions): Handle multiple exceptions. (4) Else: Execute code if no exceptions occur. (5) Finally: Run code regardless of exceptions, ensuring resource cleanup and finalization. This structure allows for robust error handling and recovery.

# %% [markdown]
# '''13. Why is memory management important in Python'''
# - Memory management is crucial in Python to prevent memory leaks, optimize performance, and avoid runtime errors. Efficient memory use ensures that programs can handle large datasets, scale well, and run smoothly. Proper memory management also helps reduce the risk of crashes, freezes, and other issues, resulting in more reliable and maintainable applications.

# %% [markdown]
# '''14. What is the role of try and except in exception handling'''
# - The try block contains code that may raise an exception, while the except block catches and handles exceptions that occur in the try block. The try block is executed, and if an exception occurs, the corresponding except block is executed to handle the exception, preventing program termination and allowing for error recovery and graceful handling.

# %% [markdown]
# '''15. How does Python's garbage collection system work'''
# - Python's garbage collector automatically frees memory occupied by objects no longer referenced. It uses reference counting, where objects are deleted when their reference count reaches zero. Additionally, a generational garbage collector periodically cleans up cyclic references, ensuring efficient memory management and preventing memory leaks in Python applications.

# %% [markdown]
# '''16. What is the purpose of the else block in exception handling'''
# - The else block in exception handling is used to execute code when no exceptions occur in the try block. It allows for separating normal execution from error handling, making code more readable and maintainable. The else block is executed only if the try block completes without raising an exception, enabling additional processing or actions.

# %% [markdown]
# '''17. What are the common logging levels in Python'''
# - Python's logging module provides several levels, including: DEBUG (detailed information), INFO (general events), WARNING (potential issues), ERROR (errors that prevent normal execution), and CRITICAL (critical errors that require attention). These levels allow for filtering and handling log messages based on severity, making it easier to monitor and debug applications.

# %% [markdown]
# '''18. What is the difference between os.fork() and multiprocessing in Python'''
# - os.fork() creates a new process by duplicating the parent process, while multiprocessing provides a higher-level interface for parallelism. os.fork() is Unix-specific, whereas multiprocessing is cross-platform. multiprocessing also offers more features, such as process pools and queues, for easier parallel processing.

# %% [markdown]
# '''19. What is the importance of closing a file in Python'''
# - Closing a file in Python is crucial to free up system resources, prevent file descriptor leaks, and ensure data integrity. Unclosed files can lead to memory issues, file corruption, and unexpected behavior. Closing files also allows other processes to access them, making it a good practice for efficient and reliable file handling.

# %% [markdown]
# '''20. What is the difference between file.read() and file.readline() in Python'''
# - File.read() reads the entire contents of a file into a string, while file.readline() reads a single line from the file. read() returns all data at once, whereas readline() returns one line at a time, allowing for more controlled reading of large files or line-by-line processing.

# %% [markdown]
# '''21. What is the logging module in Python used for'''
# - The logging module is used for recording events in a program, providing a flexible framework for logging messages at different levels (debug, info, warning, error, critical). It helps with debugging, testing, and monitoring applications, allowing you to configure log output, format, and severity levels for effective error tracking and analysis.

# %% [markdown]
# '''22. What is the os module in Python used for in file handling'''
# - The os module provides functions for interacting with the operating system, particularly for file handling. It's used for tasks like creating and deleting directories, checking file existence, and working with file paths. The os module offers a way to perform file system operations in a platform-independent manner, making it a versatile tool for file handling in Python applications.

# %% [markdown]
# '''23. What are the challenges associated with memory management in Python'''
# - Python's automatic memory management through garbage collection can lead to memory leaks, fragmentation, and performance issues. Large data structures, circular references, and global variables can consume excessive memory. Additionally, Python's dynamic typing and object creation can result in memory overhead, making efficient memory management crucial for optimal performance and preventing memory-related issues.

# %% [markdown]
# '''24. How do you raise an exception manually in Python'''
# - You can raise an exception manually in Python using the raise keyword followed by the exception type and a descriptive message. For example: raise ValueError("Invalid input"). This allows you to explicitly signal an error or unexpected condition in your code, providing useful information for debugging and error handling.

# %% [markdown]
# '''25. Why is it important to use multithreading in certain applications?'''
# - Multithreading is crucial in applications requiring concurrent execution, such as GUI programs, network servers, and real-time systems. It improves responsiveness, increases throughput, and enhances system utilization. By executing multiple threads simultaneously, multithreading enables efficient use of system resources, reducing idle time and improving overall performance. This is particularly important in applications with multiple tasks or user interactions.

# %%
#Practical Questions
'''01. How can you open a file for writing in Python and write a string to it'''
file_path = 'example.txt'
content = "Hello, World!"

with open(file_path, 'w') as file:
    file.write(content)
    print(content)
# Out:
# Hello, World!

# %%
'''02. Write a Python program to read the contents of a file and print each line'''
def print_file_lines(file_path):
    try:
        with open(file_path, 'r') as file:
            for line in file:
                print(line.strip())
    except FileNotFoundError:
        print(f"File '{file_path}' not found.")

file_path = 'example.txt'
print_file_lines(file_path)
# Out:
# Hello, World!

# %%
'''03. How would you handle a case where the file doesn't exist while trying to open it for reading'''
try:
    with open('examplee.txt', 'r') as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print("File not found. Please check the file path.")
# Out:
# File not found. Please check the file path.

# %%
'''04. Write a Python script that reads from one file and writes its content to another file'''
def copy_file_content(source_file, destination_file):
    try:
        with open(source_file, 'r') as source:
            content = source.read()
        with open(destination_file, 'w') as destination:
            destination.write(content)
        print(f"Content copied from {source_file} to {destination_file}")
    except FileNotFoundError:
        print(f"File {source_file} not found.")

source_file = 'source.txt'
destination_file = 'destination.txt'
copy_file_content(source_file, destination_file)
# Out:
# Content copied from source.txt to destination.txt

# %%
'''05. How would you catch and handle division by zero error in Python'''
try:
    numerator = 10
    denominator = 0
    result = numerator / denominator
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Error: Division by zero is not allowed.

# %%
'''06. Write a Python program that logs an error message to a log file when a division by zero exception occurs'''
import logging

# Set up logging configuration
logging.basicConfig(filename='error.log', level=logging.ERROR)

def divide_numbers(numerator, denominator):
    try:
        result = numerator / denominator
        return result
    except ZeroDivisionError as e:
        logging.error(f"Error: {e}")

numerator = 10
denominator = 0
result = divide_numbers(numerator, denominator)

# %%
'''07. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module'''
import logging

# Set up logging configuration
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def main():
    # Log an info message
    logging.info('This is an info message')

    # Log a warning message
    logging.warning('This is a warning message')

    # Log an error message
    logging.error('This is an error message')

    # Log a debug message (will not be logged since level is set to INFO)
    logging.debug('This is a debug message')

if __name__ == '__main__':
    main()

# %%
'''08. Write a program to handle a file opening error using exception handling'''
def open_file(file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            print(content)
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except PermissionError:
        print(f"Error: Permission denied to open file '{file_path}'.")
    except OSError as e:
        print(f"Error: An error occurred while opening file '{file_path}': {e}")

file_path = 'examplee.txt'
open_file(file_path)
# Out:
# Error: File 'examplee.txt' not found.

# %%
'''09. How can you read a file line by line and store its content in a list in Python'''
def read_file(file_path):
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()
            return [line.strip() for line in lines]
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return []

file_path = 'example.txt'
content = read_file(file_path)
print(content)
# Out:
# ['Hello, World!']

# %%
'''10. How can you append data to an existing file in Python'''
def append_to_file(file_path, data):
    try:
        with open(file_path, 'a') as file:
            file.write(data + '\n')
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")

file_path = 'example.txt'
data = 'This is some new data.'
append_to_file(file_path,data)
open_file(file_path)
# Out:
# Hello, World!This is some new data.

# %%
'''11. Write a Python program that uses a try-except block to handle an error when attempting to access a 
dictionary key that doesn't exist'''
def access_dictionary_key(dictionary, key):
    try:
        value = dictionary[key]
        print(f"The value of '{key}' is: {value}")
    except KeyError:
        print(f"Error: Key '{key}' not found in the dictionary.")

my_dict = {'name': 'John', 'age': 30}
key = 'city'
access_dictionary_key(my_dict, key)
# Out:
# Error: Key 'city' not found in the dictionary.

# %%
'''12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions'''
def divide_numbers(numerator, denominator):
    try:
        result = numerator / denominator
        print(f"The result is: {result}")
    except ZeroDivisionError:
        print("Error: Division by zero is not allowed.")
    except TypeError:
        print("Error: Invalid data type. Please enter numbers only.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Test cases
divide_numbers(10, 2)  # Successful division
divide_numbers(10, 0)  # Division by zero
divide_numbers(10, 'a')  # Invalid data type
divide_numbers(None, 2)  # Unexpected error
# Out:
# The result is: 5.0
# Error: Division by zero is not allowed.
# Error: Invalid data type. Please enter numbers only.
# Error: Invalid data type. Please enter numbers only.

# %%
'''14. Write a program that uses the logging module to log both informational and error messages'''
import logging

# Set up logging configuration
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def main():
    try:
        # Log an informational message
        logging.info('Program started successfully')

        # Simulate an error
        x = 1 / 0

    except ZeroDivisionError as e:
        # Log an error message
        logging.error(f'An error occurred: {e}')

if __name__ == '__main__':
    main()

# %%
'''15. Write a Python program that prints the content of a file and handles the case when the file is empty'''
def print_file_content(file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            if content:
                print(content)
            else:
                print(f"File '{file_path}' is empty.")
    except FileNotFoundError:
        print(f"File '{file_path}' not found.")

file_path = 'example.txt'
print_file_content(file_path)
# Out:
# Hello, World!This is some new data.

# %%
'''16. Demonstrate how to use memory profiling to check the memory usage of a small program'''
import tracemalloc

def memory_intensive_function():
    # Create a large list
    large_list = [i for i in range(10**6)]
    return large_list

# Start tracing memory allocation
tracemalloc.start()

# Call the memory-intensive function
large_list = memory_intensive_function()

# Get the current and peak memory usage
current, peak = tracemalloc.get_traced_memory()
print(f"Current memory usage: {current / 10**6:.2f} MB")
print(f"Peak memory usage: {peak / 10**6:.2f} MB")

# Stop tracing memory allocation
tracemalloc.stop()
# Out:
# Current memory usage: 40.45 MB
# Peak memory usage: 40.46 MB

# %%
'''17. Write a Python program to create and write a list of numbers to a file, one number per line'''
numbers = [1, 2, 3, 4, 5]

with open('numbers.txt', 'w') as file:
    for number in numbers:
        file.write(str(number) + '\n')

print("Numbers written to numbers.txt")
# Out:
# Numbers written to numbers.txt

# %%
'''18. How would you implement a basic logging setup that logs to a file with rotation after 1MB'''
import logging
from logging.handlers import RotatingFileHandler

# Set up logging configuration
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

# Set up rotating file handler
file_handler = RotatingFileHandler('app.log', maxBytes=1024*1024, backupCount=5)
file_handler.setLevel(logging.DEBUG)

# Set up formatter
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler.setFormatter(formatter)

# Add handler to logger
logger.addHandler(file_handler)

# Log some messages
logger.debug('This is a debug message.')
logger.info('This is an info message.')
logger.warning('This is a warning message.')
logger.error('This is an error message.')
logger.critical('This is a critical message.')

# %%
'''19. Write a program that handles both IndexError and KeyError using a try-except block'''
def handle_errors():
    try:
        my_list = [1, 2, 3]
        print(my_list[5])  # Raises IndexError

        my_dict = {'a': 1, 'b': 2}
        print(my_dict['c'])  # Raises KeyError
    except IndexError:
        print("IndexError: Index out of range.")
    except KeyError:
        print("KeyError: Key not found.")

handle_errors()
# Out:
# IndexError: Index out of range.

# %%
'''20. How would you open a file and read its contents using a context manager in Python'''
with open('example.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Hello, World!This is some new data.

# %%
'''21. Write a Python program that reads a file and prints the number of occurrences of a specific word'''
def count_word_occurrences(file_path, word):
    try:
        with open(file_path, 'r') as file:
            content = file.read().lower()
            occurrences = content.count(word.lower())
            print(f"The word '{word}' occurs {occurrences} times in the file.")
    except FileNotFoundError:
        print(f"File '{file_path}' not found.")

file_path = 'example.txt'
word = 'hello'
count_word_occurrences(file_path, word)
# Out:
# The word 'hello' occurs 1 times in the file.

# %%
'''22. How can you check if a file is empty before attempting to read its contents'''
import os

file_path = 'example.txt'
if os.path.getsize(file_path) == 0:
    print(f"File '{file_path}' is empty.")
else:
    with open(file_path, 'r') as file:
        content = file.read()
        print(content)
# Out:
# Hello, World!This is some new data.

# %%
'''23. Write a Python program that writes to a log file when an error occurs during file handling'''
import logging

# Set up logging configuration
logging.basicConfig(
    filename='error.log',
    level=logging.ERROR,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

def read_file(file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            return content
    except FileNotFoundError:
        logging.error(f"File '{file_path}' not found.")
    except PermissionError:
        logging.error(f"Permission denied to access file '{file_path}'.")
    except Exception as e:
        logging.error(f"An error occurred: {str(e)}")

# Example usage
file_path = 'non_existent_file.txt'
read_file(file_path)
